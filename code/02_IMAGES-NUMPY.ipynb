# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from IPython.display import Image

# %%
from IPython.core.display import HTML

# %%
img = Image(url= "https://www.chicagoparent.com/downloads/21168/download/adorable-puppy.jpg?cb=ceb03b5cdefa3c132db18811980d0ee2&w=1000&h=660",width=1000, height=1000)
img
# Out:
# <img src="https://www.chicagoparent.com/downloads/21168/download/adorable-puppy.jpg?cb=ceb03b5cdefa3c132db18811980d0ee2&w=1000&h=660" width="1000" height="1000"/>

# %%
from PIL import Image

# %%
pic = Image.open('data/puppy.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x700 at 0x117F3DEB0>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
#transform this picture into an array
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (700, 1000, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
# LETS VISUALIZE THE CHANNEL RED
pic_red[:,:,0]
# Out:
# array([[226, 226, 226, ..., 173, 173, 174],
#        [226, 226, 226, ..., 172, 172, 171],
#        [226, 226, 226, ..., 170, 169, 169],
#        ...,
#        [120, 123, 127, ...,  90,  92,  94],
#        [118, 121, 125, ...,  92,  94,  94],
#        [117, 119, 124, ...,  93,  94,  94]], dtype=uint8)

# %%
plt.imshow(pic_red[:,:,1]) 
# matplotlibe use the colorscale here to map colors 
# https://matplotlib.org/3.1.1/gallery/color/colormap_reference.html

# %%
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
# LETS VISUALIZE THE CHANNEL GREEN
pic_red[:,:,1]
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
# LETS VISUALIZE THE CHANNEL GREEN
pic_red[:,:,2]
plt.imshow(pic_red[:,:,2], cmap='gray')

# %%
# LETS MODIFY NOW THE GREEN CHANNEL
pic_red[:,:,1]=0
plt.imshow(pic_red)

# %%
# LETS MODIFY NOW THE BLUE CHANNEL
pic_red[:,:,2]=0
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (700, 1000, 3)
