# %%
from IPython.display import Image
from IPython.core.display import HTML 

import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# RGB SPACE 
Image(url= "https://i.pinimg.com/originals/bf/2d/0e/bf2d0e090f386111cae1d8e06d4f0015.jpg",width=600, height=600)
# Out:
# <img src="https://i.pinimg.com/originals/bf/2d/0e/bf2d0e090f386111cae1d8e06d4f0015.jpg" width="600" height="600"/>

# %%
# HSV SPACE
Image(url= "https://image1.slideserve.com/3312174/slide1-n.jpg",width=600, height=600)
# Out:
# <img src="https://image1.slideserve.com/3312174/slide1-n.jpg" width="600" height="600"/>

# %%
# HSL SPACE
Image(url= "https://upload.wikimedia.org/wikipedia/commons/thumb/3/35/HSL_color_solid_cylinder.png/800px-HSL_color_solid_cylinder.png",width=600, height=600)
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/35/HSL_color_solid_cylinder.png/800px-HSL_color_solid_cylinder.png" width="600" height="600"/>

# %%
img = cv2.imread('/Users/aldo/Desktop/mact/urban-panopticon/data/puppy.jpg')
img  = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_RGB2HLS)
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img)
