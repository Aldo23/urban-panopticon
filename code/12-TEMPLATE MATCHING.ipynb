# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplolib inline
# Out:
# UsageError: Line magic function `%matplolib` not found.

# %%
full = cv2.imread('data/puppy.jpg')
full = cv2.cvtColor(full, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(full)

# %%
face = cv2.imread('data/puppy-face.jpg')
face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
plt.imshow(face)

# %%
# now copy and paste a list of methods for template matching
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR', 'cv2.TM_CCORR_NORMED','cv2.TM_SQDIFF','cv2.TM_SQDIFF_NORM']

# %%
# we will do a for loop through all those methods

for m in methods: 
    
    #create a copy
    full_copy = full.copy()
    method = eval(m)
    
    #template matching
    res = cv2.matchTemplate(full_copy,face,method)
    
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
        
    else:
        top_left = max_loc 
        
    height, width, channels = face.shape
    
    bottom_right = (top_left[0] + width, top_left[1]+height)
    
    cv2.rectangle(full_copy, top_left, bottom_right,(255,0,0),10)
    
    # PLOT AND SHOW IMAGES
    
    plt.subplot(121)
    plt.imshow(res)
    plt.title('HEATMAP OF TEMPLATE MATCHING')
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title('DETECTION OF TEMPLATE')
    
    #TITLE WITH METHOD USDE
    plt.suptitle(m)
    plt.show()
    
    print('\n')
    print('\n')

# %%
# what loop does
my_method = eval('cv2.TM_CCOEFF')
res = cv2.matchTemplate(full,face,my_method)
plt.imshow(res)

# %%
#highest values where you think he is finding the highest correlation in the image
