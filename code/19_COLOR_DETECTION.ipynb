# %%
import cv2
import imutils
import numpy as np
import copy
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-a4f8bdee170e> in <module>
#       1 import cv2
# ----> 2 import imutils
#       3 import numpy as np
#       4 import copy
#       5 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'imutils'

# %%
img = cv2.imread('./data/test-street-02.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d8dcffe8f181> in <module>
#       1 img = cv2.imread('./data/test-street-02.jpg')
# ----> 2 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#       3 img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#
# NameError: name 'plt' is not defined

# %%
lower_range = np.array([20, 100, 00])
upper_range = np.array([30, 255, 255])
mask = cv2.inRange(img, lower_range, upper_range)
img = cv2.cvtColor(img, cv2.COLOR_HSV2BGR)
plt.imshow(cv2.cvtColor(mask, cv2.COLOR_BGR2RGB))

# %%
res = cv2.bitwise_and(img, img, mask=mask)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
